# %%
# Dependencies
import pandas as pd 
import numpy as np
import requests
import json

# %%
# Import file and read csv
file = "Resources/gender_obesity.csv"

o_df = pd.read_csv(file)
o_df
# Out:
#            ID  YearStart  YearEnd  Description LocationAbbr LocationDesc  \
# 0    193288.0     2020.0   2020.0       2020.0           US     National
# 1    193289.0     2020.0   2020.0       2020.0           US     National
# 2    193368.0     2020.0   2020.0       2020.0           AL      Alabama
# 3    193369.0     2020.0   2020.0       2020.0           AL      Alabama
# 4    193395.0     2020.0   2020.0       2020.0           AK       Alaska
# ..        ...        ...      ...          ...          ...          ...
# 112       NaN        NaN      NaN          NaN          NaN          NaN
# 113       NaN        NaN      NaN          NaN          NaN          NaN
# 114       NaN        NaN      NaN          NaN          NaN          NaN
# 115       NaN        NaN      NaN          NaN          NaN          NaN
# 116       NaN        NaN      NaN          NaN          NaN          NaN
#
#     DataSource                    Class                    Topic  \
# 0        BRFSS  Obesity / Weight Status  Obesity / Weight Status
# 1        BRFSS  Obesity / Weight Status  Obesity / Weight Status
# 2        BRFSS  Obesity / Weight Status  Obesity / Weight Status
# 3        BRFSS  Obesity / Weight Status  Obesity / Weight Status
# 4        BRFSS  Obesity / Weight Status  Obesity / Weight Status
# ..         ...                      ...                      ...
# 112        NaN                      NaN                      NaN
# 113        NaN                      NaN                      NaN
# 114        NaN                      NaN                      NaN
# 115        NaN                      NaN                      NaN
# 116        NaN                      NaN                      NaN
#
#                                               Question  ...  \
# 0    Percent of adults aged 18 years and older who ...  ...
# 1    Percent of adults aged 18 years and older who ...  ...
# 2    Percent of adults aged 18 years and older who ...  ...
# 3    Percent of adults aged 18 years and older who ...  ...
# 4    Percent of adults aged 18 years and older who ...  ...
# ..                                                 ...  ...
# 112                                                NaN  ...
# 113                                                NaN  ...
# 114                                                NaN  ...
# 115                                                NaN  ...
# 116                                                NaN  ...
#
#      StratificationId2  StratificationCategory3 StratificationCategoryId3  \
# 0                  NaN                      NaN                       NaN
# 1                  NaN                      NaN                       NaN
# 2                  NaN                      NaN                       NaN
# 3                  NaN                      NaN                       NaN
# 4                  NaN                      NaN                       NaN
# ..                 ...                      ...                       ...
# 112                NaN                      NaN                       NaN
# 113                NaN                      NaN                       NaN
# 114                NaN                      NaN                       NaN
# 115                NaN                      NaN                       NaN
# 116                NaN                      NaN                       NaN
#
#     Stratification3  StratificationId3  LocationDisplayOrder  FootnoteSymbol  \
# 0               NaN                NaN                   0.0             NaN
# 1               NaN                NaN                   0.0             NaN
# 2               NaN                NaN                   1.0             NaN
# 3               NaN                NaN                   1.0             NaN
# 4               NaN                NaN                   2.0             NaN
# ..              ...                ...                   ...             ...
# 112             NaN                NaN                   NaN             NaN
# 113             NaN                NaN                   NaN             NaN
# 114             NaN                NaN                   NaN             NaN
# 115             NaN                NaN                   NaN             NaN
# 116             NaN                NaN                   NaN             NaN
#
#                                           FootnoteText  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 112  Division of Nutrition, Physical Activity, and ...
# 113                                  Physical Activity
# 114    Chronic Disease Prevention and Health Promotion
# 115                             Overweight and Obesity
# 116                           State and Local Programs
#
#                                                 URL FootnoteHeading
# 0                                               NaN             NaN
# 1                                               NaN             NaN
# 2                                               NaN             NaN
# 3                                               NaN             NaN
# 4                                               NaN             NaN
# ..                                              ...             ...
# 112                       /nccdphp/dnpao/index.html   Related Links
# 113                    /physicalactivity/index.html   Related Links
# 114                       /chronicdisease/index.htm   Related Links
# 115                             /obesity/index.html   Related Links
# 116  /nccdphp/dnpao/state-local-programs/index.html   Related Links
#
# [117 rows x 43 columns]

# %%
# List columns
o_df.columns
# Out:
# Index(['ID', 'YearStart', 'YearEnd', 'Description', 'LocationAbbr',
#        'LocationDesc', 'DataSource', 'Class', 'Topic', 'Question', 'Response',
#        'Data_Value_Unit', 'DataValueTypeId', 'Data_Value_Type', 'Data_Value',
#        'Data_Value_Footnote_Symbol', 'Data_Value_Footnote',
#        'Low_Confidence_Limit', 'High_Confidence_Limit', 'Sample_Size',
#        'GeoLocation_Lat', 'GeoLocation_Long', 'ClassId', 'TopicId',
#        'QuestionId', 'ResponseId', 'StratficationCategory1',
#        'StratificationCategoryId1', 'Stratification1', 'StratificationId1',
#        'StratificationCategory2', 'StratificationCategoryId2',
#        'Stratification2', 'StratificationId2', 'StratificationCategory3',
#        'StratificationCategoryId3', 'Stratification3', 'StratificationId3',
#        'LocationDisplayOrder', 'FootnoteSymbol', 'FootnoteText', 'URL',
#        'FootnoteHeading'],
#       dtype='object')

# %%
# Delete extraneous columns
o_clean_df = o_df[['Description','LocationDesc','Class', 'Question','Data_Value','Stratification1']]
o_clean_df
# Out:
#      Description LocationDesc                    Class  \
# 0         2020.0     National  Obesity / Weight Status
# 1         2020.0     National  Obesity / Weight Status
# 2         2020.0      Alabama  Obesity / Weight Status
# 3         2020.0      Alabama  Obesity / Weight Status
# 4         2020.0       Alaska  Obesity / Weight Status
# ..           ...          ...                      ...
# 112          NaN          NaN                      NaN
# 113          NaN          NaN                      NaN
# 114          NaN          NaN                      NaN
# 115          NaN          NaN                      NaN
# 116          NaN          NaN                      NaN
#
#                                               Question  Data_Value  \
# 0    Percent of adults aged 18 years and older who ...        31.7
# 1    Percent of adults aged 18 years and older who ...        32.1
# 2    Percent of adults aged 18 years and older who ...        37.7
# 3    Percent of adults aged 18 years and older who ...        40.3
# 4    Percent of adults aged 18 years and older who ...        33.8
# ..                                                 ...         ...
# 112                                                NaN         NaN
# 113                                                NaN         NaN
# 114                                                NaN         NaN
# 115                                                NaN         NaN
# 116                                                NaN         NaN
#
#     Stratification1
# 0              Male
# 1            Female
# 2              Male
# 3            Female
# 4              Male
# ..              ...
# 112             NaN
# 113             NaN
# 114             NaN
# 115             NaN
# 116             NaN
#
# [117 rows x 6 columns]

# %%
# Identify empty rows
o_clean_df.count()
# Out:
# Description        108
# LocationDesc       108
# Class              108
# Question           108
# Data_Value         108
# Stratification1    108
# dtype: int64

# %%
# Remove empty rows
o_clean_df = o_clean_df.dropna(how='any')

# %%
o_clean_df
# Out:
#      Description LocationDesc                    Class  \
# 0         2020.0     National  Obesity / Weight Status
# 1         2020.0     National  Obesity / Weight Status
# 2         2020.0      Alabama  Obesity / Weight Status
# 3         2020.0      Alabama  Obesity / Weight Status
# 4         2020.0       Alaska  Obesity / Weight Status
# ..           ...          ...                      ...
# 103       2020.0      Wyoming  Obesity / Weight Status
# 104       2020.0         Guam  Obesity / Weight Status
# 105       2020.0         Guam  Obesity / Weight Status
# 106       2020.0  Puerto Rico  Obesity / Weight Status
# 107       2020.0  Puerto Rico  Obesity / Weight Status
#
#                                               Question  Data_Value  \
# 0    Percent of adults aged 18 years and older who ...        31.7
# 1    Percent of adults aged 18 years and older who ...        32.1
# 2    Percent of adults aged 18 years and older who ...        37.7
# 3    Percent of adults aged 18 years and older who ...        40.3
# 4    Percent of adults aged 18 years and older who ...        33.8
# ..                                                 ...         ...
# 103  Percent of adults aged 18 years and older who ...        31.4
# 104  Percent of adults aged 18 years and older who ...        33.8
# 105  Percent of adults aged 18 years and older who ...        35.1
# 106  Percent of adults aged 18 years and older who ...        28.4
# 107  Percent of adults aged 18 years and older who ...        34.1
#
#     Stratification1
# 0              Male
# 1            Female
# 2              Male
# 3            Female
# 4              Male
# ..              ...
# 103          Female
# 104            Male
# 105          Female
# 106            Male
# 107          Female
#
# [108 rows x 6 columns]

# %%
# Rename columns
o_clean_df = o_clean_df.rename(columns={"Description":"Year","LocationDesc":"State","Data_Value":"Obese Average (%)","Stratification1":"Gender"})
o_clean_df
# Out:
#        Year        State                    Class  \
# 0    2020.0     National  Obesity / Weight Status
# 1    2020.0     National  Obesity / Weight Status
# 2    2020.0      Alabama  Obesity / Weight Status
# 3    2020.0      Alabama  Obesity / Weight Status
# 4    2020.0       Alaska  Obesity / Weight Status
# ..      ...          ...                      ...
# 103  2020.0      Wyoming  Obesity / Weight Status
# 104  2020.0         Guam  Obesity / Weight Status
# 105  2020.0         Guam  Obesity / Weight Status
# 106  2020.0  Puerto Rico  Obesity / Weight Status
# 107  2020.0  Puerto Rico  Obesity / Weight Status
#
#                                               Question  Obese Average (%)  \
# 0    Percent of adults aged 18 years and older who ...               31.7
# 1    Percent of adults aged 18 years and older who ...               32.1
# 2    Percent of adults aged 18 years and older who ...               37.7
# 3    Percent of adults aged 18 years and older who ...               40.3
# 4    Percent of adults aged 18 years and older who ...               33.8
# ..                                                 ...                ...
# 103  Percent of adults aged 18 years and older who ...               31.4
# 104  Percent of adults aged 18 years and older who ...               33.8
# 105  Percent of adults aged 18 years and older who ...               35.1
# 106  Percent of adults aged 18 years and older who ...               28.4
# 107  Percent of adults aged 18 years and older who ...               34.1
#
#      Gender
# 0      Male
# 1    Female
# 2      Male
# 3    Female
# 4      Male
# ..      ...
# 103  Female
# 104    Male
# 105  Female
# 106    Male
# 107  Female
#
# [108 rows x 6 columns]

# %%
# Remove national rows
o_final_df = o_clean_df.drop(o_clean_df.index[[0,1]])
o_final_df
# Out:
#        Year        State                    Class  \
# 2    2020.0      Alabama  Obesity / Weight Status
# 3    2020.0      Alabama  Obesity / Weight Status
# 4    2020.0       Alaska  Obesity / Weight Status
# 5    2020.0       Alaska  Obesity / Weight Status
# 6    2020.0      Arizona  Obesity / Weight Status
# ..      ...          ...                      ...
# 103  2020.0      Wyoming  Obesity / Weight Status
# 104  2020.0         Guam  Obesity / Weight Status
# 105  2020.0         Guam  Obesity / Weight Status
# 106  2020.0  Puerto Rico  Obesity / Weight Status
# 107  2020.0  Puerto Rico  Obesity / Weight Status
#
#                                               Question  Obese Average (%)  \
# 2    Percent of adults aged 18 years and older who ...               37.7
# 3    Percent of adults aged 18 years and older who ...               40.3
# 4    Percent of adults aged 18 years and older who ...               33.8
# 5    Percent of adults aged 18 years and older who ...               29.6
# 6    Percent of adults aged 18 years and older who ...               30.8
# ..                                                 ...                ...
# 103  Percent of adults aged 18 years and older who ...               31.4
# 104  Percent of adults aged 18 years and older who ...               33.8
# 105  Percent of adults aged 18 years and older who ...               35.1
# 106  Percent of adults aged 18 years and older who ...               28.4
# 107  Percent of adults aged 18 years and older who ...               34.1
#
#      Gender
# 2      Male
# 3    Female
# 4      Male
# 5    Female
# 6      Male
# ..      ...
# 103  Female
# 104    Male
# 105  Female
# 106    Male
# 107  Female
#
# [106 rows x 6 columns]

# %%
# Organize dataframe by obese average
highest = o_final_df.sort_values("Obese Average (%)", ascending=False)
highest
# Out:
#       Year                 State                    Class  \
# 51  2020.0           Mississippi  Obesity / Weight Status
# 98  2020.0         West Virginia  Obesity / Weight Status
# 3   2020.0               Alabama  Obesity / Weight Status
# 39  2020.0             Louisiana  Obesity / Weight Status
# 83  2020.0        South Carolina  Obesity / Weight Status
# ..     ...                   ...                      ...
# 12  2020.0              Colorado  Obesity / Weight Status
# 13  2020.0              Colorado  Obesity / Weight Status
# 45  2020.0         Massachusetts  Obesity / Weight Status
# 25  2020.0                Hawaii  Obesity / Weight Status
# 18  2020.0  District of Columbia  Obesity / Weight Status
#
#                                              Question  Obese Average (%)  \
# 51  Percent of adults aged 18 years and older who ...               42.8
# 98  Percent of adults aged 18 years and older who ...               40.6
# 3   Percent of adults aged 18 years and older who ...               40.3
# 39  Percent of adults aged 18 years and older who ...               39.8
# 83  Percent of adults aged 18 years and older who ...               39.4
# ..                                                ...                ...
# 12  Percent of adults aged 18 years and older who ...               24.3
# 13  Percent of adults aged 18 years and older who ...               24.1
# 45  Percent of adults aged 18 years and older who ...               23.4
# 25  Percent of adults aged 18 years and older who ...               22.3
# 18  Percent of adults aged 18 years and older who ...               19.1
#
#     Gender
# 51  Female
# 98    Male
# 3   Female
# 39  Female
# 83  Female
# ..     ...
# 12    Male
# 13  Female
# 45  Female
# 25  Female
# 18    Male
#
# [106 rows x 6 columns]

# %%
# Organize by lowest obese average
lowest = o_final_df.sort_values("Obese Average (%)")
lowest
# Out:
#       Year                 State                    Class  \
# 18  2020.0  District of Columbia  Obesity / Weight Status
# 25  2020.0                Hawaii  Obesity / Weight Status
# 45  2020.0         Massachusetts  Obesity / Weight Status
# 13  2020.0              Colorado  Obesity / Weight Status
# 12  2020.0              Colorado  Obesity / Weight Status
# ..     ...                   ...                      ...
# 83  2020.0        South Carolina  Obesity / Weight Status
# 39  2020.0             Louisiana  Obesity / Weight Status
# 3   2020.0               Alabama  Obesity / Weight Status
# 98  2020.0         West Virginia  Obesity / Weight Status
# 51  2020.0           Mississippi  Obesity / Weight Status
#
#                                              Question  Obese Average (%)  \
# 18  Percent of adults aged 18 years and older who ...               19.1
# 25  Percent of adults aged 18 years and older who ...               22.3
# 45  Percent of adults aged 18 years and older who ...               23.4
# 13  Percent of adults aged 18 years and older who ...               24.1
# 12  Percent of adults aged 18 years and older who ...               24.3
# ..                                                ...                ...
# 83  Percent of adults aged 18 years and older who ...               39.4
# 39  Percent of adults aged 18 years and older who ...               39.8
# 3   Percent of adults aged 18 years and older who ...               40.3
# 98  Percent of adults aged 18 years and older who ...               40.6
# 51  Percent of adults aged 18 years and older who ...               42.8
#
#     Gender
# 18    Male
# 25  Female
# 45  Female
# 13  Female
# 12    Male
# ..     ...
# 83  Female
# 39  Female
# 3   Female
# 98    Male
# 51  Female
#
# [106 rows x 6 columns]
